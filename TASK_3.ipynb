# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('E:/Project_3/Advertising.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
# Unnamed: 0    200 non-null int64
# TV            200 non-null float64
# Radio         200 non-null float64
# Newspaper     200 non-null float64
# Sales         200 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# ##### there is noy null value present in this data se and we have 200 data set with 5 coloum , there is 4 features 3 is predictors and 1 is responce variables

# %%
### get some statical information abou data

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
### check if there is some duplicate entry are there or not
df.duplicated().sum()
# Out:
# 0

# %%
# univariant analysis

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df,x=df['TV'],y=df['Sales'])
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df,x=df['Radio'],y=df['Sales'])
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df,x=df['Newspaper'],y=df['Sales'])
plt.show()

# %% [markdown]
# #### we have seen beutifull relationship between predictor and responce variable also we find that conclution there is  good relationship "TV" and "Sales"

# %% [markdown]
# ### that means from all of the 3 predictors "TV" coloum is most important one becouse it shows good linear relation ship with "sales"

# %%
### just split the data set
Predictors=df.drop('Sales',axis=1)

# %%
Predictors
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# 5             6    8.7   48.9       75.0
# 6             7   57.5   32.8       23.5
# 7             8  120.2   19.6       11.6
# 8             9    8.6    2.1        1.0
# 9            10  199.8    2.6       21.2
# 10           11   66.1    5.8       24.2
# 11           12  214.7   24.0        4.0
# 12           13   23.8   35.1       65.9
# 13           14   97.5    7.6        7.2
# 14           15  204.1   32.9       46.0
# 15           16  195.4   47.7       52.9
# 16           17   67.8   36.6      114.0
# 17           18  281.4   39.6       55.8
# 18           19   69.2   20.5       18.3
# 19           20  147.3   23.9       19.1
# 20           21  218.4   27.7       53.4
# 21           22  237.4    5.1       23.5
# ...

# %%
y=df['Sales']

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
# 5       7.2
# 6      11.8
# 7      13.2
# 8       4.8
# 9      10.6
# 10      8.6
# 11     17.4
# 12      9.2
# 13      9.7
# 14     19.0
# 15     22.4
# 16     12.5
# 17     24.4
# 18     11.3
# 19     14.6
# 20     18.0
# 21     12.5
# 22      5.6
# 23     15.5
# 24      9.7
# 25     12.0
# 26     15.0
# 27     15.9
# 28     18.9
# 29     10.5
#        ...
# 170     8.4
# 171    14.5
# 172     7.6
# 173    11.7
# 174    11.5
# 175    27.0
# 176    20.2
# 177    11.7
# 178    11.8
# 179    12.6
# 180    10.5
# 181    12.2
# 182     8.7
# 183    26.2
# 184    17.6
# 185    22.6
# 186    10.3
# 187    17.3
# 188    15.9
# 189     6.7
# 190    10.8
# 191     9.9
# 192     5.9
# 193    19.6
# 194    17.3
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
### split in training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size = 0.20, random_state = 0)

# %%
### just applying very simple linear regresssion
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#fitting the model to the dataset
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_predictions=model.predict(X_test)

# %%
y_predictions
# Out:
# array([10.24664397,  7.3067958 ,  7.01313011, 24.0629912 , 11.84538583,
#         6.3623126 , 12.97367539, 15.01392577, 10.95137181, 16.2302401 ,
#        22.94764396,  9.07892877, 10.29830431, 15.372556  , 11.63358138,
#        12.38729183, 18.91996453, 10.72601207, 16.03372676, 17.36589369,
#        23.85225051,  9.51048184, 15.25366204, 12.2528663 ,  5.81346738,
#        15.19998588, 12.12398331, 20.74762723, 13.36651757,  9.16548788,
#        13.0430809 , 21.47977498, 18.01828076, 21.14170908,  6.74096317,
#         5.9527019 ,  7.82515133, 13.21661502, 14.72150697,  6.18172688])

# %%
### some KPI matrics to understand the acc

from sklearn import metrics

print('MAE:',metrics.mean_absolute_error(y_predictions,y_test))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_predictions,y_test)))
print('R-Squared',metrics.r2_score(y_predictions,y_test))
# Out:
# MAE: 1.4158480868317485
# RMSE: 2.1252030072958723
# R-Squared 0.8283777385812963
